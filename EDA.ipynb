# %%
# %matplotlib inline
import digits
from collections import Counter
from matplotlib import pyplot as plt
import random

# %%
DATA_PATH = 'digits.csv'

# %%
labels, pixels = digits.read(DATA_PATH)

# %%
label_counts = Counter(labels)
label_counts
# Out:
# Counter({1: 1095,
#          0: 991,
#          4: 967,
#          7: 1039,
#          3: 1009,
#          5: 906,
#          8: 950,
#          9: 995,
#          2: 1045,
#          6: 1003})

# %%
pixels_sq = pixels.reshape(-1, 28, 28)
pixels_sq.shape
# Out:
# (10000, 28, 28)

# %%
random.seed(0)
indices = random.sample(range(1, len(labels+1)), 10)

for index in indices:
    plt.title(labels[index])
    plt.imshow(pixels_sq[index])
    plt.show()
